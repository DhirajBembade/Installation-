# %% [markdown]
# <a href="https://colab.research.google.com/github/DhirajBembade/Installation-/blob/main/MySQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Reference :**
#
# ## installation-
#  * Youtube- https://www.youtube.com/watch?v=Rxp3T5GKlR4
#  * Website- https://www.mysql.com/
#
#  2nd page-
#
# https://www.oracle.com/search/results?cat=mysql&Ntk=SI-ALL5&Ntt=mysql+community+server
#
#  3rd page -
#
#  https://dev.mysql.com/downloads/mysql/5.6.html  select your OS system and click on **go to download page** option & Downloade lagrest file
#
#   i.e.
#
#
#  4th page-
#
#  https://dev.mysql.com/downloads/windows/installer/8.0.html   file 431.7 MB For WIn
#
#
#  Download latest version
#
# * complete installation

# %% [markdown]
# ![Screenshot 2023-01-13 020641.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-01-13 022110.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# # **Practice-**

# %% [markdown]
# ![sql shell practice.png](data:image/png;base64,...)
