# %% [markdown]
# <a href="https://colab.research.google.com/github/DhirajBembade/Installation-/blob/main/PostgreSQL%2015.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Reference :**
#
# ## installation-
#  * Youtube- https://www.youtube.com/watch?v=0n41UTkOBb0
#  * Website- https://www.postgresql.org/download/
#
#  Download latest version -
#
#  https://www.enterprisedb.com/downloads/postgres-postgresql-downloads

# %% [markdown]
# # **My Practice :**
#
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-01-11 003038.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-01-11 155634.png](data:image/png;base64,...)
