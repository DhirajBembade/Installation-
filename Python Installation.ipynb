# %% [markdown]
# <a href="https://colab.research.google.com/github/DhirajBembade/Installation-/blob/main/Python%20Installation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Python-**
#
# ---
#
#
#
# Python is an interpreted, object-oriented, high-level programming language with dynamic semantics developed by Guido van Rossum.
#
# It was originally released in 1991.
#
#  Designed to be easy as well as fun, the name "Python" is a nod to the British comedy group Monty Python.
#
#
# * What is Python used for?
#
#
# Python is a computer programming language often used to build websites and software, automate tasks, and conduct data analysis.
#
# Python is a general-purpose language, meaning it can be used to create a variety of different programs and isn't specialized for any specific problems

# %% [markdown]
# ---

# %% [markdown]
# #**Acknowledgement--**
#
#
# (Reference)
#
# Follow This steps to download Git setup:
#
# Note- Downloade Stable veriosion. Don not downloade latest version for better use.
#
#
# * https://www.python.org/downloads/  or
#
# * https://www.youtube.com/watch?v=Kn1HF3oD19c

# %% [markdown]
# ---

# %% [markdown]
# # **My Assignment-**
#
# ![Screenshot 2022-12-21 python.png](data:image/png;base64,...)
